# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhammadane/pandas-by-shubhammadane/blob/main/Numpy_Python_by_Shubham_Madane.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installation of numpy

# %%
! pip install numpy

# %%
import numpy as np

# %%
np.__version__#Check the Vesion
# Out:
# '2.0.2'

# %%
list1=[1,2,3,4,5]
list1
# Out:
# [1, 2, 3, 4, 5]

# %%
arrlist = np.array(list1)
print(arrlist)
# Out:
# [1 2 3 4 5]

# %%
print(type(arrlist))
# Out:
# <class 'numpy.ndarray'>

# %%
arrlist.ndim #Check the Arrays type
# Out:
# 1

# %%
list1=[1,2,3,4,5]
list2=[2,3,4,5,6]
arr2d= np.array([list1,list2])
print(arr2d)
# Out:
# [[1 2 3 4 5]
#  [2 3 4 5 6]]

# %%
print(arr2d.ndim)
# Out:
# 2

# %%
list1 = [11,22,33,44]
list2 = [22,33,44,55]
list3 = [33,44,55,66]

arr3d = np.array([[list1,list2,list3]])
print(arr3d)
# Out:
# [[[11 22 33 44]
#   [22 33 44 55]
#   [33 44 55 66]]]

# %%
print(arr3d.ndim)
# Out:
# 3

# %%
arr1= np.array([[11,22,33,44],[33,4,5,55,]])
print(arr1)
# Out:
# [[11 22 33 44]
#  [33  4  5 55]]

# %%
print("Shape: ",arr1.shape)
print("Size: ",arr1.size)
print("Dimension: ",arr1.ndim)
print("Datatype: ",arr1.dtype)
print("Check Type: ",type(arr1))
# Out:
# Shape:  (2, 4)
# Size:  8
# Dimension:  2
# Datatype:  int64
# Check Type:  <class 'numpy.ndarray'>
